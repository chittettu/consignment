# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\data_science\project\Internship\SCMS_Delivery_History_Dataset.csv")

# %%
df
# Out:
#           ID Project Code             PQ   PO / SO   ASN/DN         Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
data=df.to_dict(orient='records')
data
# Out:
# [{'ID': 1,
#   'Project Code': '100-CI-T01',
#   'PQ ': 'Pre-PQ Process',
#   'PO / SO ': 'SCMS-4',
#   'ASN/DN ': 'ASN-8',
#   'Country': "Côte d'Ivoire",
#   'Managed By': 'PMO - US',
#   'Fulfill Via': 'Direct Drop',
#   'Vendor INCO Term': 'EXW',
#   'Shipment Mode': 'Air',
#   'PQ First Sent to Client Date': 'Pre-PQ Process',
#   'PO Sent to Vendor Date': 'Date Not Captured',
#   'Scheduled Delivery Date': '2-Jun-06',
#   'Delivered to Client Date': '2-Jun-06',
#   'Delivery Recorded Date': '2-Jun-06',
#   'Product Group': 'HRDT',
#   'Sub Classification': 'HIV test',
#   'Vendor': 'RANBAXY Fine Chemicals LTD.',
#   'Item Description': 'HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 Tests',
#   'Molecule/Test Type': 'HIV, Reveal G3 Rapid HIV-1 Antibody Test',
#   'Brand': 'Reveal',
#   'Dosage': nan,
#   'Dosage Form': 'Test kit',
#   'Unit of Measure (Per Pack)': 30,
#   'Line Item Quantity': 19,
#   'Line Item Value': 551.0,
#   'Pack Price': 29.0,
#   'Unit Price': 0.97,
# ...

# %%
import pymongo
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://mahesh:mahesh@cluster0.gvvxc3b.mongodb.net/?retryWrites=true&w=majority")

# %%
database=client["shipment"]

# %%
COLLECTION_NAME="consignment"
collection=database[COLLECTION_NAME]

# %%
rec=collection.insert_many(data)
all_record=collection.find()
for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('65ae377c5c6bbb6b726aed1c'), 'ID': 1, 'Project Code': '100-CI-T01', 'PQ ': 'Pre-PQ Process', 'PO / SO ': 'SCMS-4', 'ASN/DN ': 'ASN-8', 'Country': "Côte d'Ivoire", 'Managed By': 'PMO - US', 'Fulfill Via': 'Direct Drop', 'Vendor INCO Term': 'EXW', 'Shipment Mode': 'Air', 'PQ First Sent to Client Date': 'Pre-PQ Process', 'PO Sent to Vendor Date': 'Date Not Captured', 'Scheduled Delivery Date': '2-Jun-06', 'Delivered to Client Date': '2-Jun-06', 'Delivery Recorded Date': '2-Jun-06', 'Product Group': 'HRDT', 'Sub Classification': 'HIV test', 'Vendor': 'RANBAXY Fine Chemicals LTD.', 'Item Description': 'HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 Tests', 'Molecule/Test Type': 'HIV, Reveal G3 Rapid HIV-1 Antibody Test', 'Brand': 'Reveal', 'Dosage': nan, 'Dosage Form': 'Test kit', 'Unit of Measure (Per Pack)': 30, 'Line Item Quantity': 19, 'Line Item Value': 551.0, 'Pack Price': 29.0, 'Unit Price': 0.97, 'Manufacturing Site': 'Ranbaxy Fine Chemicals LTD', 'First Line Des
# ...
